# %%
import pandas as pd
df = pd.read_csv("D:\Excel-files\pandas-01.csv")
df.head(5)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016         38.0      23.0      52.0                 30.03
# 1  01-02-2016         36.0      18.0      46.0                 30.02
# 2  01-03-2016         40.0      21.0      47.0                 29.86
# 3  01-04-2016         25.0       9.0      44.0                 30.05
# 4  01-05-2016         20.0      -3.0      41.0                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0             10.0           8.0               0         5.0    NaN
# 1             10.0           7.0               0         3.0    NaN
# 2             10.0           8.0               0         1.0    NaN
# 3             10.0           9.0               0         3.0    NaN
# 4             10.0           5.0               0         0.0    NaN
#
#    WindDirDegrees  Unnamed: 11
# 0           281.0          NaN
# 1           275.0          NaN
# 2           277.0          NaN
# ...

# %%
df["Temperature"].max()   # max function
# Out:
# 50.0

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8     01-09-2016
# 9     01-10-2016
# 15     1/16/2016
# 26     1/27/2016
# Name: EST, dtype: object

# %% [raw]
# df["WindSpeedMPH"].mean()

# %% [markdown]
# #The process of cleaning messy data is called data manging or data wrangling

# %%
df.fillna(0)
df.head(5)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016         38.0      23.0      52.0                 30.03
# 1  01-02-2016         36.0      18.0      46.0                 30.02
# 2  01-03-2016         40.0      21.0      47.0                 29.86
# 3  01-04-2016         25.0       9.0      44.0                 30.05
# 4  01-05-2016         20.0      -3.0      41.0                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0             10.0           8.0               0         5.0    NaN
# 1             10.0           7.0               0         3.0    NaN
# 2             10.0           8.0               0         1.0    NaN
# 3             10.0           9.0               0         3.0    NaN
# 4             10.0           5.0               0         0.0    NaN
#
#    WindDirDegrees  Unnamed: 11
# 0           281.0          NaN
# 1           275.0          NaN
# 2           277.0          NaN
# ...
